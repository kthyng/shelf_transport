# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
from IPython.core.display import Image 
import tracpy
import tracpy.plotting
#from matplotlib.mlab import Path
import netCDF4 as netCDF
# Out:
# /Users/kthyng/.virtualenvs/default/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
loc = 'http://barataria.tamu.edu:8080/thredds/dodsC/NcML/txla_nesting6.nc'
grid = tracpy.inout.readgrid(loc, usebasemap=True)

# %% [markdown]
# # Steps for Shelf Transport and Shelf Eddy Analysis and Plots for TXLA Model Output
#
# Simulations for looking at transport around the TXLA model domain and for some of the analysis for the shelf eddies were done in the `shelf_transport` project directory. Surface drifters were seeded uniformly in projected space throughout the numerical domain with 1 km spacing in both x and y. They were initialized daily from 2004 through 2010 and run for 30 days for each simulation. Subgrid diffusion was not used due to its effect on the FSLE, though an old set of simulations that did use the proper amount of subgrid diffusion for matching the mean square separation from LaCasce 2008 is available on rho.tamu.edu. The simulations used for analysis and this work are available on hafen.

# %% [markdown]
# ## TXLA transport

# %% [markdown]
# ### Cross-shelf connectivity
#
# The seasonal connectivity plot was run using `make_plots.py` in the `shelf_transport` project directory on hafen. I chose January and February to represent the winter or non-summer to avoid having to span multiple years for a season (i.e., December 2004, January 2005 and February 2005). I varied different consecutive pairs of months around summer to see which showed the shelf eddy signal most strongly. Between May-June, June-July, July-August, and August-September, the July-August combination visually gave the strongest signal for the shelf eddy region, which I am taking to mean that it best represents the distinct summer dynamics.
#
# Below are the seasonal cross-shelf connectivity plots for the 100, 50, and 20 meter isobaths.

# %%
Image('figures/seasonal100.png')

# %%
Image('figures/seasonal50.png')

# %%
Image('figures/seasonal20.png')

# %% [markdown]
# To separate out regions for different kinds of analysis, I used ginput() in Python to select out the paths representing different regions:
#
# * the full winter signal (Texas)
# * the full summer signal (Louisiana)
# * the distinct winter signal
# * the distinct summer signal
#
# See below for a visual. I selected out each path by hand with ginput on the 100 meter isobath crossing plot above, and got a path for the approximate 10, 20, and 30% contours for each region described.
#
# The indices corresponding to the seed locations for these shelf transport simulations that are within each of the regions are saved in files likes `calcs/path-pts-winter-full-10percent.npz'

# %%
fig = figure(figsize=(14,18))
ax = fig.add_subplot(111)
tracpy.plotting.background(grid, fig=fig)

### ----- Region outlines ----- ###

## --- Winter full --- ##
# - 10% - ##
d = np.load('calcs/path-pts-winter-full-10percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='green', lw=5, alpha=0.3)
# - 20% - ##
d = np.load('calcs/path-pts-winter-full-20percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='blue', lw=5, alpha=0.3)
# - 30% - ##
d = np.load('calcs/path-pts-winter-full-30percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='purple', lw=5, alpha=0.3)

## --- Summer full --- ##
# - 10% - ##
d = np.load('calcs/path-pts-summer-full-10percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='yellow', lw=5, alpha=0.3)
# - 20% - ##
d = np.load('calcs/path-pts-summer-full-20percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='orange', lw=5, alpha=0.3)
# - 30% - ##
d = np.load('calcs/path-pts-summer-full-30percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='red', lw=5, alpha=0.3)

## --- Winter part --- ##
# - 10% - ##
d = np.load('calcs/path-pts-winter-part-10percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='green', lw=3, alpha=0.9)
# - 20% - ##
d = np.load('calcs/path-pts-winter-part-20percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='blue', lw=3, alpha=0.9)
# - 30% - ##
d = np.load('calcs/path-pts-winter-part-30percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='purple', lw=3, alpha=0.9)

## --- Summer part --- ##
# - 10% - ##
d = np.load('calcs/path-pts-summer-part-10percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='yellow', lw=3, alpha=0.9)
# - 20% - ##
d = np.load('calcs/path-pts-summer-part-20percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='orange', lw=3, alpha=0.9)
# - 30% - ##
d = np.load('calcs/path-pts-summer-part-30percent.npz')
x = d['pts'][:,0]; y = d['pts'][:,1];
d.close()
plot(x, y, color='red', lw=3, alpha=0.9)

### ----- Region seed locations ----- ###

# Found by:
# l = np.load('calcs/path-pts-summer-full-20percent.npz')
# path = Path(np.vstack((l['pts'][:,0], l['pts'][:,1])).T)
# inside = find(path.contains_points(np.vstack((xp, yp)).T))
# np.savez('calcs/indsinpath-summer-full-20percent.npz', inds=inside)

## --- Winter part --- ##
# - 30% - ##
d = np.load('calcs/xyp0.npz')

dinds = np.load('calcs/indsinpath-winter-part-30percent.npz')
inds = dinds['inds']
dinds.close()
plot(d['xp0'][inds], d['yp0'][inds], '.', color='purple', lw=3, alpha=0.9, ms=.2)

d.close()

# %% [markdown]
# ### Coastline connectivity

# %%
Image('figures/coastLAseasonal.png')

# %%
Image('figures/coastCHseasonal.png')

# %%
Image('figures/coastNTXseasonal.png')

# %%
Image('figures/coastSTXseasonal.png')

# %%
Image('figures/coastMXseasonal.png')

# %% [markdown]
# ## Shelf Eddies

# %% [markdown]
# ### Metrics in Regions for Comparison

# %%
Image('figures/D2_fsle.png')

# %%
# Calculate dispersion in each of the subareas for comparison
